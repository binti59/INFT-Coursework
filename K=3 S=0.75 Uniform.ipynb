# %%
#Initial Setup for plots etc

#!pip install plotnine
import matplotlib.pyplot as plt
import numpy as np
import csv
import math
import random
import warnings
from scipy import stats
from numpy.random import seed
from numpy.random import randn
from scipy.stats import mannwhitneyu
from scipy.stats import wilcoxon
from scipy.stats import ttest_ind
from scipy.stats import shapiro
import pandas as pd
import seaborn as sns
import plotnine as p9
import glob
import os

from BSE import market_session
from BSE import Trader_PRZI_SHC

def plot_distribution(i):
    plt.figure()
    ax=sns.distplot(i)
    plt.axvline(np.mean(i),color="k",linestyle="dashed",linewidth=4)
    _,max_=plt.ylim()
    plt.text(i.mean()+(i.mean()/10),max_- max_ / 10, "Mean :{:.2f}".format(i.mean()))
    return plt.figure

def plot_trades(trial_id):
    prices_fname = trial_id + '_transactions.csv'
    x = np.empty(0)
    y = np.empty(0)
    with open(prices_fname, newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            time = float(row[1])
            price = float(row[2])
            x = np.append(x,time)
            y = np.append(y,price)

    plt.plot(x, y, 'x', color='black') 
    plt.xlabel('Time is (secs)')
    plt.ylabel('Price')
    
# Use this to run an experiment n times and plot all trades
def n_runs_plot(n, trial_id, start_time, end_time, traders_spec, order_sched):
    x = np.empty(0)
    y = np.empty(0)

    for i in range(n):
        trialId = trial_id + '_' + str(i)
        tdump = open(trialId + '_avg_balance.csv','w')

        market_session(trialId, start_time, end_time, traders_spec, order_sched, tdump, True, False)
        
        tdump.close()

        with open(trialId + '_transactions.csv', newline='') as csvfile:
            reader = csv.reader(csvfile)
            for row in reader:
                time = float(row[1])
                price = float(row[2])
                x = np.append(x,time)
                y = np.append(y,price)

    plt.plot(x, y, 'x', color='black')
    plt.xlabel('Time')
    plt.ylabel('Price');

# !!! Don't use on it's own   
def getorderprice(i, sched, n, mode):
    pmin = min(sched[0][0], sched[0][1])
    pmax = max(sched[0][0], sched[0][1])
    prange = pmax - pmin
    stepsize = prange / (n - 1)
    halfstep = round(stepsize / 2.0)

    if mode == 'fixed':
        orderprice = pmin + int(i * stepsize)
    elif mode == 'jittered':
        orderprice = pmin + int(i * stepsize) + random.randint(-halfstep, halfstep)
    elif mode == 'random':
        if len(sched) > 1:
            # more than one schedule: choose one equiprobably
            s = random.randint(0, len(sched) - 1)
            pmin = min(sched[s][0], sched[s][1])
            pmax = max(sched[s][0], sched[s][1])
        orderprice = random.randint(pmin, pmax)
    return orderprice    

# !!! Don't use on it's own
def make_supply_demand_plot(bids, asks):
    # total volume up to current order
    volS = 0
    volB = 0

    fig, ax = plt.subplots()
    plt.ylabel('Price')
    plt.xlabel('Quantity')
    
    pr = 0
    for b in bids:
        if pr != 0:
            # vertical line
            ax.plot([volB,volB], [pr,b], 'r-')
        # horizontal lines
        line, = ax.plot([volB,volB+1], [b,b], 'r-')
        volB += 1
        pr = b
    if bids:
        line.set_label('Demand')
        
    pr = 0
    for s in asks:
        if pr != 0:
            # vertical line
            ax.plot([volS,volS], [pr,s], 'b-')
        # horizontal lines
        line, = ax.plot([volS,volS+1], [s,s], 'b-')
        volS += 1
        pr = s
    if asks:
        line.set_label('Supply')
        
    if bids or asks:
        plt.legend()
    plt.show()

# Use this to plot supply and demand curves from supply and demand ranges and stepmode
def sup_dem(seller_num, sup_ranges, buyer_num, dem_ranges, stepmode):
    asks = []
    for s in range(seller_num):
        asks.append(getorderprice(s, sup_ranges, seller_num, stepmode))
    asks.sort()
    bids = []
    for b in range(buyer_num):
        bids.append(getorderprice(b, dem_ranges, buyer_num, stepmode))
    bids.sort()
    bids.reverse()
    
    make_supply_demand_plot(bids, asks) 

# plot sorted trades, useful is some situations - won't be used in this worksheet
def in_order_plot(trial_id):
    prices_fname = trial_id + '_transactions.csv'
    y = np.empty(0)
    with open(prices_fname, newline='') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            price = float(row[2])
            y = np.append(y,price)
    y = np.sort(y)
    x = list(range(len(y)))

    plt.plot(x, y, 'x', color='black')

# %%
start_time = 0
end_time = 60 * 60
sup_range=(100,200)
dem_range=(100,200)

supply_schedule = [{'from': start_time, 'to': end_time, 'ranges': [sup_range], 'stepmode': 'fixed'}]
demand_schedule = [{'from': start_time, 'to': end_time, 'ranges': [dem_range], 'stepmode': 'fixed'}]

sellers_spec = [("PRSH",10),("ZIP",10)]
buyers_spec = [("PRSH",10),("ZIP",10)]
traders_spec ={"sellers" : sellers_spec, "buyers": buyers_spec}

order_interval = 60
order_sched = {'sup': supply_schedule, 'dem': demand_schedule,
               'interval': order_interval, 'timemode': 'periodic'}

verbose = True
#tdump=open('Test_avg_balance.csv','w')
trial_id = 'Test'
dump_all = True
#market_session(trial_id, start_time, end_time, traders_spec, order_sched, tdump, dump_all, verbose)
#tdump.close()

sup_dem(10, [sup_range], 10, [dem_range], 'fixed')
#plot_trades('Test')
n_runs_plot(50, trial_id, start_time, end_time, traders_spec, order_sched)
# Out:
# PRSH B00 PRSH: B00 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=0.609274, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B01 PRSH: B01 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.484449, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B02 PRSH: B02 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.311659, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=-0.039856, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B03 PRSH: B03 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.902199, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B04 PRSH: B04 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.059921, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B05 PRSH: B05 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B06 PRSH: B06 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=-0.148674, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=0.419305, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B07 PRSH: B07 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.746266, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B08 PRSH: B08 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.219334, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH B09 PRSH: B09 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.509858, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=0.022651, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S00 PRSH: S00 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.143512, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S01 PRSH: S01 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=-0.184667, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S02 PRSH: S02 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=-0.075167, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S03 PRSH: S03 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.546736, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S04 PRSH: S04 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.318944, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=0.105649, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S05 PRSH: S05 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.074337, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=0.382392, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S06 PRSH: S06 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.476877, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=0.189819, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S07 PRSH: S07 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.465904, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=0.958869, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S08 PRSH: S08 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=0.465646, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=0.346280, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# PRSH S09 PRSH: S09 active_strat=[0]:
# [0]: s=0.750000, start=0.000000, $=0.000000, pps=0.000000
# [1]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
# [2]: s=1.000000, start=0.000000, $=0.000000, pps=0.000000
#
#
# 3
# t=300.025000 B03 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B06 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B08 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B09 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B10 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B12 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B13 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B15 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B17 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 B19 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S01 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S05 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S07 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S08 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S09 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S10 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S12 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S15 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S16 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=300.025000 S17 PRSH respond: strat[0] elapsed=300.025000; wait_t=300.000000, switched to strat=1
# t=600.050000 B03 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B06 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B08 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B09 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B10 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B12 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B13 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B15 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B17 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 B19 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S01 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S05 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S07 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S08 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S09 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S10 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S12 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S15 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S16 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# t=600.050000 S17 PRSH respond: strat[1] elapsed=300.025000; wait_t=300.000000, switched to strat=2
# PRSH B03: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.509858, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.022651, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# B03: strat_eval_time=900.000000, MUTATED:
# s=0.509858 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.659383 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B06: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=-0.148674, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.419305, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# B06: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.601758 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B08: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# B08: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.532390 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.635245 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B09: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.311659, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=-0.039856, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# B09: strat_eval_time=900.000000, MUTATED:
# s=0.311659 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.076865 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.477696 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B10: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=1.000000, pps=0.001111
# s=0.059921, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# B10: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.295077 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B12: strat_eval_time=900.000000, all_old_enough=True
# s=0.609274, start_t=0.000000, lifetime=900.050000, $=22.000000, pps=0.024443
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=18.000000, pps=0.019999
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=12.000000, pps=0.013333
# B12: strat_eval_time=900.000000, MUTATED:
# s=0.609274 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.043666 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B13: strat_eval_time=900.000000, all_old_enough=True
# s=0.902199, start_t=0.000000, lifetime=900.050000, $=42.000000, pps=0.046664
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=36.000000, pps=0.039998
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=32.000000, pps=0.035554
# B13: strat_eval_time=900.000000, MUTATED:
# s=0.902199 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.899366 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.412423 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B15: strat_eval_time=900.000000, all_old_enough=True
# s=0.219334, start_t=0.000000, lifetime=900.050000, $=75.000000, pps=0.083329
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=61.000000, pps=0.067774
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=56.000000, pps=0.062219
# B15: strat_eval_time=900.000000, MUTATED:
# s=0.219334 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.537006 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B17: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=150.000000, pps=0.166657
# s=0.746266, start_t=0.000000, lifetime=900.050000, $=135.000000, pps=0.149992
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=99.000000, pps=0.109994
# B17: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.207156 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.859846 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B19: strat_eval_time=900.000000, all_old_enough=True
# s=0.484449, start_t=0.000000, lifetime=900.050000, $=206.000000, pps=0.228876
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=150.000000, pps=0.166657
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=130.000000, pps=0.144436
# B19: strat_eval_time=900.000000, MUTATED:
# s=0.484449 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.229249 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.067548 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S01: strat_eval_time=900.000000, all_old_enough=True
# s=0.074337, start_t=0.000000, lifetime=900.050000, $=208.000000, pps=0.231098
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=161.000000, pps=0.178879
# s=0.382392, start_t=0.000000, lifetime=900.050000, $=98.000000, pps=0.108883
# S01: strat_eval_time=900.000000, MUTATED:
# s=0.074337 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.333222 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.336737 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S05: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=171.000000, pps=0.189989
# s=0.546736, start_t=0.000000, lifetime=900.050000, $=67.000000, pps=0.074440
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=53.000000, pps=0.058886
# S05: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.107878 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.256364 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S07: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=70.000000, pps=0.077773
# s=0.465904, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.958869, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# S07: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.471416 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.520028 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S08: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=99.000000, pps=0.109994
# s=-0.184667, start_t=0.000000, lifetime=900.050000, $=48.000000, pps=0.053330
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# S08: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.546975 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.894984 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S09: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=63.000000, pps=0.069996
# s=-0.075167, start_t=0.000000, lifetime=900.050000, $=18.000000, pps=0.019999
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# S09: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.168542 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.278088 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S10: strat_eval_time=900.000000, all_old_enough=True
# s=0.318944, start_t=0.000000, lifetime=900.050000, $=8.000000, pps=0.008888
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.105649, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# S10: strat_eval_time=900.000000, MUTATED:
# s=0.318944 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.894962 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.288818 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S12: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.143512, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# S12: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.177809 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S15: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.465646, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.346280, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# S15: strat_eval_time=900.000000, MUTATED:
# s=0.465646 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.374159 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S16: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.476877, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=0.189819, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# S16: strat_eval_time=900.000000, MUTATED:
# s=0.476877 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.735885 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S17: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# s=1.000000, start_t=0.000000, lifetime=900.050000, $=0.000000, pps=0.000000
# S17: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.252766 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.823674 start_t=900.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# t=900.125000 B03 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B06 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B08 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B09 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B10 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B12 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B13 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B15 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B17 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 B19 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S01 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S05 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S07 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S08 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S09 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S10 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S12 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S15 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S16 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=900.125000 S17 PRSH respond: strat[2] elapsed=300.075000; wait_t=300.000000, switched to strat=0
# t=1200.125000 B03 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B06 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B08 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B09 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B10 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B12 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B13 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B15 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B17 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 B19 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S01 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S05 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S07 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S08 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S09 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S10 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S12 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S15 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S16 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1200.125000 S17 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=1500.125000 B03 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B06 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B08 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B09 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B10 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B12 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B13 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B15 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B17 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 B19 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S01 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S05 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S07 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S08 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S09 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S10 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S12 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S15 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S16 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=1500.125000 S17 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# PRSH B03: strat_eval_time=900.000000, all_old_enough=True
# s=0.509858, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.659383, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B03: strat_eval_time=900.000000, MUTATED:
# s=0.509858 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.380024 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.177418 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B06: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.601758, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B06: strat_eval_time=900.000000, MUTATED:
# s=0.601758 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.448874 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.094941 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B08: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.532390, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.635245, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B08: strat_eval_time=900.000000, MUTATED:
# s=0.532390 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.296856 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.030590 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B09: strat_eval_time=900.000000, all_old_enough=True
# s=0.311659, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.076865, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.477696, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B09: strat_eval_time=900.000000, MUTATED:
# s=0.311659 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.381576 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.634959 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B10: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=900.050000, lifetime=900.000000, $=5.000000, pps=0.005556
# s=0.295077, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B10: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.173188 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B12: strat_eval_time=900.000000, all_old_enough=True
# s=0.609274, start_t=900.050000, lifetime=900.000000, $=45.000000, pps=0.050000
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=12.000000, pps=0.013333
# s=-0.043666, start_t=900.050000, lifetime=900.000000, $=7.000000, pps=0.007778
# B12: strat_eval_time=900.000000, MUTATED:
# s=0.609274 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.152519 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.230884 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B13: strat_eval_time=900.000000, all_old_enough=True
# s=0.902199, start_t=900.050000, lifetime=900.000000, $=77.000000, pps=0.085556
# s=0.899366, start_t=900.050000, lifetime=900.000000, $=38.000000, pps=0.042222
# s=0.412423, start_t=900.050000, lifetime=900.000000, $=38.000000, pps=0.042222
# B13: strat_eval_time=900.000000, MUTATED:
# s=0.902199 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.780431 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.612897 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B15: strat_eval_time=900.000000, all_old_enough=True
# s=0.219334, start_t=900.050000, lifetime=900.000000, $=121.000000, pps=0.134444
# s=0.537006, start_t=900.050000, lifetime=900.000000, $=94.000000, pps=0.104444
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=76.000000, pps=0.084444
# B15: strat_eval_time=900.000000, MUTATED:
# s=0.219334 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.725351 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.058961 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B17: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=900.050000, lifetime=900.000000, $=167.000000, pps=0.185556
# s=0.859846, start_t=900.050000, lifetime=900.000000, $=121.000000, pps=0.134444
# s=0.207156, start_t=900.050000, lifetime=900.000000, $=116.000000, pps=0.128889
# B17: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.342613 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B19: strat_eval_time=900.000000, all_old_enough=True
# s=0.484449, start_t=900.050000, lifetime=900.000000, $=240.000000, pps=0.266667
# s=0.067548, start_t=900.050000, lifetime=900.000000, $=203.000000, pps=0.225556
# s=-0.229249, start_t=900.050000, lifetime=900.000000, $=177.000000, pps=0.196667
# B19: strat_eval_time=900.000000, MUTATED:
# s=0.484449 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.176407 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S01: strat_eval_time=900.000000, all_old_enough=True
# s=-0.333222, start_t=900.050000, lifetime=900.000000, $=267.000000, pps=0.296667
# s=-0.336737, start_t=900.050000, lifetime=900.000000, $=256.000000, pps=0.284444
# s=0.074337, start_t=900.050000, lifetime=900.000000, $=136.000000, pps=0.151111
# S01: strat_eval_time=900.000000, MUTATED:
# s=-0.333222 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.200016 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.181690 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S05: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=142.000000, pps=0.157778
# s=0.107878, start_t=900.050000, lifetime=900.000000, $=138.000000, pps=0.153333
# s=0.256364, start_t=900.050000, lifetime=900.000000, $=63.000000, pps=0.070000
# S05: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.432693 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.607770 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S07: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.471416, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.520028, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# S07: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.748116 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.044085 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S08: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=58.000000, pps=0.064444
# s=0.546975, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.894984, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# S08: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.518414 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.750302 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S09: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=34.000000, pps=0.037778
# s=0.278088, start_t=900.050000, lifetime=900.000000, $=7.000000, pps=0.007778
# s=0.168542, start_t=900.050000, lifetime=900.000000, $=6.000000, pps=0.006667
# S09: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.187684 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.273917 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S10: strat_eval_time=900.000000, all_old_enough=True
# s=0.318944, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.894962, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.288818, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# S10: strat_eval_time=900.000000, MUTATED:
# s=0.894962 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.011236 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S12: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=5.000000, pps=0.005556
# s=0.750000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=-0.177809, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# S12: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.478470 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.502177 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S15: strat_eval_time=900.000000, all_old_enough=True
# s=0.465646, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.374159, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# S15: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.336904 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.172488 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S16: strat_eval_time=900.000000, all_old_enough=True
# s=0.476877, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.735885, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# S16: strat_eval_time=900.000000, MUTATED:
# s=0.476877 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.004249 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.657966 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S17: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.252766, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.823674, start_t=900.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# S17: strat_eval_time=900.000000, MUTATED:
# s=0.252766 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.288056 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.821018 start_t=1800.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# t=1800.175000 B03 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B06 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B08 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B09 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B10 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B12 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B13 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B15 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B17 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 B19 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S01 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S05 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S07 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S08 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S09 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S10 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S12 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S15 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S16 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=1800.175000 S17 PRSH respond: strat[2] elapsed=300.050000; wait_t=300.000000, switched to strat=0
# t=2100.275000 B03 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B06 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B08 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B09 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B10 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B12 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B13 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B15 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B17 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 B19 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S01 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S05 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S07 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S08 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S09 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S10 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S12 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S15 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S16 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2100.275000 S17 PRSH respond: strat[0] elapsed=300.100000; wait_t=300.000000, switched to strat=1
# t=2400.275000 B03 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B06 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B08 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B09 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B10 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B12 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B13 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B15 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B17 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 B19 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S01 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S05 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S07 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S08 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S09 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S10 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S12 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S15 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S16 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=2400.275000 S17 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# PRSH B03: strat_eval_time=900.000000, all_old_enough=True
# s=0.509858, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.380024, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=-0.177418, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B03: strat_eval_time=900.000000, MUTATED:
# s=0.509858 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.515694 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.236429 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B06: strat_eval_time=900.000000, all_old_enough=True
# s=0.601758, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.448874, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.094941, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B06: strat_eval_time=900.000000, MUTATED:
# s=0.448874 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.431149 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B08: strat_eval_time=900.000000, all_old_enough=True
# s=0.532390, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=-0.296856, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.030590, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B08: strat_eval_time=900.000000, MUTATED:
# s=-0.296856 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-1.000000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.583177 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B09: strat_eval_time=900.000000, all_old_enough=True
# s=0.311659, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=0.381576, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# s=-0.634959, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B09: strat_eval_time=900.000000, MUTATED:
# s=0.381576 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.296895 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B10: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=1800.050000, lifetime=900.000000, $=30.000000, pps=0.033333
# s=1.000000, start_t=1800.050000, lifetime=900.000000, $=1.000000, pps=0.001111
# s=-0.173188, start_t=1800.050000, lifetime=900.000000, $=0.000000, pps=0.000000
# B10: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.686569 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B12: strat_eval_time=900.000000, all_old_enough=True
# s=0.609274, start_t=1800.050000, lifetime=900.000000, $=65.000000, pps=0.072222
# s=-0.152519, start_t=1800.050000, lifetime=900.000000, $=16.000000, pps=0.017778
# s=0.230884, start_t=1800.050000, lifetime=900.000000, $=2.000000, pps=0.002222
# B12: strat_eval_time=900.000000, MUTATED:
# s=0.609274 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.581858 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B13: strat_eval_time=900.000000, all_old_enough=True
# s=0.902199, start_t=1800.050000, lifetime=900.000000, $=69.000000, pps=0.076667
# s=0.780431, start_t=1800.050000, lifetime=900.000000, $=40.000000, pps=0.044444
# s=0.612897, start_t=1800.050000, lifetime=900.000000, $=16.000000, pps=0.017778
# B13: strat_eval_time=900.000000, MUTATED:
# s=0.902199 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B15: strat_eval_time=900.000000, all_old_enough=True
# s=0.219334, start_t=1800.050000, lifetime=900.000000, $=133.000000, pps=0.147778
# s=-0.058961, start_t=1800.050000, lifetime=900.000000, $=47.000000, pps=0.052222
# s=-0.725351, start_t=1800.050000, lifetime=900.000000, $=30.000000, pps=0.033333
# B15: strat_eval_time=900.000000, MUTATED:
# s=0.219334 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.815494 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.896515 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B17: strat_eval_time=900.000000, all_old_enough=True
# s=0.750000, start_t=1800.050000, lifetime=900.000000, $=132.000000, pps=0.146667
# s=0.342613, start_t=1800.050000, lifetime=900.000000, $=110.000000, pps=0.122222
# s=1.000000, start_t=1800.050000, lifetime=900.000000, $=83.000000, pps=0.092222
# B17: strat_eval_time=900.000000, MUTATED:
# s=0.750000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.222014 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.050000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B19: strat_eval_time=900.000000, all_old_enough=True
# s=0.484449, start_t=1800.050000, lifetime=900.000000, $=238.000000, pps=0.264444
# s=0.176407, start_t=1800.050000, lifetime=900.000000, $=172.000000, pps=0.191111
# ...
# B06: strat_eval_time=900.000000, MUTATED:
# s=0.071586 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.724050 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.052056 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B08: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.656971, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.446106, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# B08: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.930415 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.653984 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B10: strat_eval_time=900.000000, all_old_enough=True
# s=0.817511, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.180797, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# B10: strat_eval_time=900.000000, MUTATED:
# s=0.817511 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.047062 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B12: strat_eval_time=900.000000, all_old_enough=True
# s=0.375580, start_t=1800.050000, lifetime=900.025000, $=49.000000, pps=0.054443
# s=0.859020, start_t=1800.050000, lifetime=900.025000, $=23.000000, pps=0.025555
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=12.000000, pps=0.013333
# B12: strat_eval_time=900.000000, MUTATED:
# s=0.375580 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.203364 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.360840 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B14: strat_eval_time=900.000000, all_old_enough=True
# s=0.303570, start_t=1800.050000, lifetime=900.025000, $=86.000000, pps=0.095553
# s=0.797193, start_t=1800.050000, lifetime=900.025000, $=52.000000, pps=0.057776
# s=0.992109, start_t=1800.050000, lifetime=900.025000, $=14.000000, pps=0.015555
# B14: strat_eval_time=900.000000, MUTATED:
# s=0.303570 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.600323 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.042271 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B17: strat_eval_time=900.000000, all_old_enough=True
# s=0.518810, start_t=1800.050000, lifetime=900.025000, $=148.000000, pps=0.164440
# s=0.839918, start_t=1800.050000, lifetime=900.025000, $=105.000000, pps=0.116663
# s=0.605889, start_t=1800.050000, lifetime=900.025000, $=61.000000, pps=0.067776
# B17: strat_eval_time=900.000000, MUTATED:
# s=0.518810 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B18: strat_eval_time=900.000000, all_old_enough=True
# s=0.281209, start_t=1800.050000, lifetime=900.025000, $=186.000000, pps=0.206661
# s=-0.656195, start_t=1800.050000, lifetime=900.025000, $=157.000000, pps=0.174440
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=90.000000, pps=0.099997
# B18: strat_eval_time=900.000000, MUTATED:
# s=0.281209 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.466691 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.371996 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH B19: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=206.000000, pps=0.228883
# s=0.181239, start_t=1800.050000, lifetime=900.025000, $=197.000000, pps=0.218883
# s=0.764656, start_t=1800.050000, lifetime=900.025000, $=117.000000, pps=0.129996
# B19: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.411219 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.538164 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S00: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=290.000000, pps=0.322213
# s=0.269870, start_t=1800.050000, lifetime=900.025000, $=224.000000, pps=0.248882
# s=0.276959, start_t=1800.050000, lifetime=900.025000, $=145.000000, pps=0.161107
# S00: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.443046 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.538651 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S01: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=351.000000, pps=0.389989
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=281.000000, pps=0.312214
# s=0.736042, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# S01: strat_eval_time=900.000000, MUTATED:
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.891270 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.587264 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S03: strat_eval_time=900.000000, all_old_enough=True
# s=-1.000000, start_t=1800.050000, lifetime=900.025000, $=216.000000, pps=0.239993
# s=-0.341807, start_t=1800.050000, lifetime=900.025000, $=190.000000, pps=0.211105
# s=0.191477, start_t=1800.050000, lifetime=900.025000, $=87.000000, pps=0.096664
# S03: strat_eval_time=900.000000, MUTATED:
# s=-1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.736103 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.568020 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S04: strat_eval_time=900.000000, all_old_enough=True
# s=0.029116, start_t=1800.050000, lifetime=900.025000, $=185.000000, pps=0.205550
# s=-0.669611, start_t=1800.050000, lifetime=900.025000, $=168.000000, pps=0.186661
# s=0.156325, start_t=1800.050000, lifetime=900.025000, $=82.000000, pps=0.091109
# S04: strat_eval_time=900.000000, MUTATED:
# s=0.029116 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.953713 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.796592 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S09: strat_eval_time=900.000000, all_old_enough=True
# s=0.453321, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.953428, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.260644, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# S09: strat_eval_time=900.000000, MUTATED:
# s=0.453321 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.022252 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.506652 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S10: strat_eval_time=900.000000, all_old_enough=True
# s=0.836380, start_t=1800.050000, lifetime=900.025000, $=19.000000, pps=0.021111
# s=0.777448, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.166228, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# S10: strat_eval_time=900.000000, MUTATED:
# s=0.836380 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.815593 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S13: strat_eval_time=900.000000, all_old_enough=True
# s=-0.003856, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.083344, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.079262, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# S13: strat_eval_time=900.000000, MUTATED:
# s=-0.003856 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.828609 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.158809 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S14: strat_eval_time=900.000000, all_old_enough=True
# s=0.744864, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.569809, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# S14: strat_eval_time=900.000000, MUTATED:
# s=0.744864 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=1.000000 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S15: strat_eval_time=900.000000, all_old_enough=True
# s=0.237117, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.863667, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.467254, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# S15: strat_eval_time=900.000000, MUTATED:
# s=0.237117 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.053927 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=-0.226048 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# PRSH S18: strat_eval_time=900.000000, all_old_enough=True
# s=1.000000, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.173018, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# s=0.551488, start_t=1800.050000, lifetime=900.025000, $=0.000000, pps=0.000000
# S18: strat_eval_time=900.000000, MUTATED:
# s=0.173018 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.227808 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# s=0.364284 start_t=2700.075000, lifetime=0.000000, $=0.000000, pps=0.000000
# t=2700.250000 B00 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B02 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B06 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B08 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B10 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B12 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B14 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B17 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B18 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 B19 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S00 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S01 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S03 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S04 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S09 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S10 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S13 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S14 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S15 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=2700.250000 S18 PRSH respond: strat[2] elapsed=300.000000; wait_t=300.000000, switched to strat=0
# t=3000.250000 B00 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B02 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B06 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B08 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B10 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B12 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B14 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B17 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B18 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 B19 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S00 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S01 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S03 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S04 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S09 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S10 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S13 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S14 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S15 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3000.250000 S18 PRSH respond: strat[0] elapsed=300.000000; wait_t=300.000000, switched to strat=1
# t=3300.250000 B00 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B02 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B06 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B08 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B10 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B12 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B14 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B17 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B18 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 B19 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S00 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S01 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S03 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S04 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S09 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S10 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S13 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S14 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S15 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2
# t=3300.250000 S18 PRSH respond: strat[1] elapsed=300.000000; wait_t=300.000000, switched to strat=2

# %%
# merging the files
joined_files = os.path.join("", "Test_*_avg_balance.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)


columns=["Trial_id","Time elapsed","Buy","Sell","Trading Algorithm PRSH",
           "Total Profit for PRSH","Total Traders PRSH","Average Profit PRSH","Trading Algorithm ZIP",
           "Total Profit for ZIP","Total Traders ZIP","Average Profit ZIP","Buy1","Sell1"]

dfcol=[]
for i,file_name in enumerate(joined_list):
    df1=pd.read_csv(file_name,names=columns,index_col=False)
    dfcol.append(df1)
df = pd.concat(dfcol)

# %%
#Tests for Normality (Shapiro-Wilk Test)
from scipy.stats import shapiro
shapiro=shapiro(df['Average Profit PRSH'])
print(shapiro)
# Out:
# ShapiroResult(statistic=0.9701175093650818, pvalue=0.0)
# C:\Users\jh21478\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1681: UserWarning: p-value may not be accurate for N > 5000.

# %%
mannwhitneyu(df['Average Profit PRSH'],df['Average Profit ZIP'])
#wilcoxon(df['Average Profit TA1'],df['Average Profit TA2'])
# Out:
# MannwhitneyuResult(statistic=248200630.0, pvalue=8.968342406010801e-37)

# %%
plot_distribution(df['Average Profit PRSH'])
# Out:
# C:\Users\jh21478\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
#Rearranging the data for plotting
df1=pd.concat([df["Trading Algorithm PRSH"],df["Trading Algorithm ZIP"]],axis=0)
df2=pd.concat([df["Average Profit PRSH"],df["Average Profit ZIP"]],axis=0)
df3=pd.concat([df1,df2],axis=1)
df3.columns=["Trading Algorithm","Average Profit Per Trader"]
#print (df3

# %%
plot_distribution(df['Average Profit ZIP'])
# Out:
# C:\Users\jh21478\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
p9.ggplot(df3)+ p9.aes(x='Average Profit Per Trader', fill='Trading Algorithm') + p9.geom_density(alpha=0.5)
# Out:
# <ggplot: (138217247220)>
